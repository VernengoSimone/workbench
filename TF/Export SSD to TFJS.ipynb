# %%
import os
from shutil import copyfile
import tensorflow
from google.colab import drive

workspace_dir = "/content/drive/MyDrive/Colab Notebooks/Thesis/workspace/training"

drive.mount('/content/drive')

# model folders:
# .../Thesis/workspace/training/pre-trained-models/ssd320
# .../Thesis/workspace/training/pre-trained-models/ssdfpn320
# Out:
# Mounted at /content/drive

# %%
! python --version
# Out:
# Python 3.7.10

# %%
! pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 71kB 3.2MB/s
# ...
#      |████████████████████████████████| 112kB 6.9MB/s
# ...
#   Found existing installation: tensorflow-hub 0.11.0
#     Uninstalling tensorflow-hub-0.11.0:
#       Successfully uninstalled tensorflow-hub-0.11.0
# ...

# %%
os.listdir("/content/drive/MyDrive/Colab Notebooks/Thesis/workspace/training/pre-trained-models")
# Out:
# ['ssdfpn640',
#  'ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz',
#  'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz',
#  'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz',
#  'centernet_mobilenetv2fpn_512x512_coco17_od.tar.gz',
#  'ssd320',
#  'models',
#  'ssdfpn320',
#  'centernet',
#  'tfjs']

# %%
os.chdir(workspace_dir)

! tensorflowjs_converter \
    --input_format=tf_saved_model \
    --saved_model_tags=serve \
    ./pre-trained-models/ssdfpn640/exported_model/saved_model \
    ./pre-trained-models/tfjs
# Out:
# 2021-03-26 13:39:37.757519: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-26 13:39:40.412340: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-26 13:39:40.413293: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-26 13:39:40.422863: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-03-26 13:39:40.422930: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (046f3041eb96): /proc/driver/nvidia/version does not exist
# 2021-03-26 13:39:40.423446: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...
